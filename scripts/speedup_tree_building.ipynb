# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.generate_trees import calc_score, two_tail_prob

# %%
import pandas as pd
import numpy as np

# %%
faunastep = 0.5

# %%
detections = pd.DataFrame()

detections["id"] = [0, 1, 2]
detections["time"] = [0, 1, 2]
detections["object_location"] = [0, 0.5, 2]

# %%
detections = pd.read_csv('../data/detections.csv')

# %%
detections
# Out:
#     id  camera_location  time  object_location
# 0    0              0.0     0         0.292697
# 1    1              0.5     1         0.323818
# 2    2              2.0     4         2.433088
# 3    3              2.0     4         2.430191
# 4    4              2.5     5         2.391798
# 5    5              2.5     5         2.494960
# 6    6              3.0     6         2.513292
# 7    7              3.0     6         2.537622
# 8    8              7.0    14         7.162219
# 9    9              7.5    15         7.119493
# 10  10              7.5    15         7.801735
# 11  11              8.0    16         7.801142

# %%
n_dets = len(detections)

dists = np.zeros((len(detections), len(detections)))
Dtime = np.zeros((len(detections), len(detections)))
for i in range(n_dets):
    for j in range(n_dets):
        dists[i, j] = np.abs(detections.loc[i]["object_location"] - detections.loc[j]["object_location"])
        Dtime[i, j] = np.abs(detections.loc[i]["time"] - detections.loc[j]["time"])

# %%
dists
# Out:
# array([[0.00000000e+00, 3.11211932e-02, 2.14039136e+00, 2.13749401e+00,
#         2.09910120e+00, 2.20226277e+00, 2.22059555e+00, 2.24492518e+00,
#         6.86952248e+00, 6.82679660e+00, 7.50903816e+00, 7.50844525e+00],
#        [3.11211932e-02, 0.00000000e+00, 2.10927017e+00, 2.10637282e+00,
#         2.06798001e+00, 2.17114158e+00, 2.18947435e+00, 2.21380398e+00,
#         6.83840129e+00, 6.79567540e+00, 7.47791697e+00, 7.47732406e+00],
#        [2.14039136e+00, 2.10927017e+00, 0.00000000e+00, 2.89734374e-03,
#         4.12901593e-02, 6.18714099e-02, 8.02041884e-02, 1.04533819e-01,
#         4.72913112e+00, 4.68640524e+00, 5.36864680e+00, 5.36805390e+00],
#        [2.13749401e+00, 2.10637282e+00, 2.89734374e-03, 0.00000000e+00,
#         3.83928156e-02, 6.47687537e-02, 8.31015321e-02, 1.07431163e-01,
#         4.73202847e+00, 4.68930258e+00, 5.37154414e+00, 5.37095124e+00],
#        [2.09910120e+00, 2.06798001e+00, 4.12901593e-02, 3.83928156e-02,
#         0.00000000e+00, 1.03161569e-01, 1.21494348e-01, 1.45823979e-01,
#         4.77042128e+00, 4.72769540e+00, 5.40993696e+00, 5.40934406e+00],
#        [2.20226277e+00, 2.17114158e+00, 6.18714099e-02, 6.47687537e-02,
#         1.03161569e-01, 0.00000000e+00, 1.83327785e-02, 4.26624093e-02,
#         4.66725971e+00, 4.62453383e+00, 5.30677539e+00, 5.30618249e+00],
#        [2.22059555e+00, 2.18947435e+00, 8.02041884e-02, 8.31015321e-02,
#         1.21494348e-01, 1.83327785e-02, 0.00000000e+00, 2.43296308e-02,
#         4.64892694e+00, 4.60620105e+00, 5.28844261e+00, 5.28784971e+00],
#        [2.24492518e+00, 2.21380398e+00, 1.04533819e-01, 1.07431163e-01,
#         1.45823979e-01, 4.26624093e-02, 2.43296308e-02, 0.00000000e+00,
#         4.62459730e+00, 4.58187142e+00, 5.26411298e+00, 5.26352008e+00],
#        [6.86952248e+00, 6.83840129e+00, 4.72913112e+00, 4.73202847e+00,
#         4.77042128e+00, 4.66725971e+00, 4.64892694e+00, 4.62459730e+00,
#         8.54517694e-02,            nan,            inf, 1.36329731e+00],
#        [1.00120509e+00, 1.06827385e+00, 9.76117600e-01, 9.76644390e-01,
#         1.08198739e+00, 1.06135508e+00, 1.17520947e+00, 1.16980288e+00,
#         1.27903135e+00,            inf,            nan, 1.18580701e-03],
#        [9.38555657e-01, 9.96976542e-01, 8.94675649e-01, 8.95158540e-01,
#         9.83517101e-01, 9.64760452e-01, 1.05756994e+00, 1.05270402e+00,
#         6.38922773e-01, 1.36329731e+00, 1.18580701e-03,            nan]])

# %%
two_tail_prob(z_stat)
# Out:
# array([[       nan, 0.95036981, 0.28453124, 0.28518368, 0.40111   ,
#         0.37836918, 0.45917955, 0.45427416, 0.32641507, 0.36269619,
#         0.31672767, 0.34795893],
#        [0.95036981,        nan, 0.15967065, 0.16024485, 0.30114084,
#         0.27766893, 0.38114435, 0.37587538, 0.29277123, 0.33164252,
#         0.285397  , 0.3187759 ],
#        [0.28453124, 0.15967065,        nan, 0.        , 0.93418525,
#         0.90151891, 0.93607486, 0.91674573, 0.34423723, 0.3941732 ,
#         0.32900619, 0.3709605 ],
#        [0.28518368, 0.16024485, 0.        ,        nan, 0.93879408,
#         0.89693235, 0.93377081, 0.91444693, 0.3439417 , 0.3938809 ,
#         0.32874523, 0.37070234],
#        [0.40111   , 0.30114084, 0.93418525, 0.93879408,        nan,
#         0.        , 0.80801415, 0.7705558 , 0.28910201, 0.34438373,
#         0.27925813, 0.325353  ],
#        [0.37836918, 0.27766893, 0.90151891, 0.89693235, 0.        ,
#                nan, 0.97075167, 0.93200316, 0.29965718, 0.35501441,
#         0.28852856, 0.33466481],
#        [0.45917955, 0.38114435, 0.93607486, 0.93377081, 0.80801415,
#         0.97075167,        nan, 0.        , 0.24514135, 0.30602413,
#         0.23991092, 0.29025155],
#        [0.45427416, 0.37587538, 0.91674573, 0.91444693, 0.7705558 ,
#         0.93200316, 0.        ,        nan, 0.24762008, 0.30858594,
#         0.2420803 , 0.29247667],
#        [0.32641507, 0.29277123, 0.34423723, 0.3439417 , 0.28910201,
#         0.29965718, 0.24514135, 0.24762008,        nan, 0.93190224,
#         0.20088602, 0.52287317],
#        [0.36269619, 0.33164252, 0.3941732 , 0.3938809 , 0.34438373,
#         0.35501441, 0.30602413, 0.30858594, 0.93190224,        nan,
#         0.        , 0.17278883],
#        [0.31672767, 0.285397  , 0.32900619, 0.32874523, 0.27925813,
#         0.28852856, 0.23991092, 0.2420803 , 0.20088602, 0.        ,
#                nan, 0.99905386],
#        [0.34795893, 0.3187759 , 0.3709605 , 0.37070234, 0.325353  ,
#         0.33466481, 0.29025155, 0.29247667, 0.52287317, 0.17278883,
#         0.99905386,        nan]])

# %%
def make_hypothesis_tree(detections, faunastep):
    branches = []
    scores = []

    times = detections.time.unique()
    times.sort()
    
    n_dets = len(detections)

    dists = np.zeros((len(detections), len(detections)))
    Dtime = np.zeros((len(detections), len(detections)))
    for i in range(n_dets):
        for j in range(n_dets):
            dists[i, j] = np.abs(detections.loc[i]["object_location"] - detections.loc[j]["object_location"])
            Dtime[i, j] = np.abs(detections.loc[i]["time"] - detections.loc[j]["time"])

    z_stat = np.divide(dists,faunastep*Dtime)
    probz = two_tail_prob(z_stat)
    
    # todo:
    #     pre-generate probabilities between all the detections

    # go through each timestep
    for t in times:
        print("timestep: {}".format(t))

        # get all detections made at that timestep
        det_t = detections[detections["time"] == t]

        # make some lists to fill
        new_branches = []
        new_scores = []

        # iterate over the detections
        for i, d in det_t.iterrows():
#             print(d["id"])
            if t == 0:
                new_br = np.array([d["id"]])
                new_score = 1

                new_branches.append(new_br)
                new_scores.append(new_score)

            else:
                # create new vector (case where this detection is a new individual)
                new_br = np.empty(t + 1)
                new_br[:] = np.NaN
                new_br[t] = d["id"]

                # add this to the new branches for this timestep
                new_branches.append(new_br)

                # add a score (of zero) for this case
                new_scores.append(1)

                # iterate over existing branches
                for i, br in enumerate(branches):
                    # get the id of the last detection in the current branch
                    last_detection = np.array(br)[np.logical_not(np.isnan(br))][-1]

                    # case where this is a repeat of the last observed
                    new_br_repeat = np.append(br, d["id"])
                    new_branches.append(new_br_repeat)

                    # calculate score
#                     scr = calc_score_row(detections[detections["id"] == last_detection], d, faunastep)
                    
                    scr = probz[int(last_detection), int(d["id"])]

                    #                 print(len(scores), len(new_scores))
                    new_scores.append(scores[i] + scr)

                    # case where it's not
                    new_br_no_repeat = np.append(br, np.NaN)
                    new_branches.append(new_br_no_repeat)

                    new_scores.append(scores[i] + 1 - scr)

            branches = new_branches
            scores = new_scores
    return branches, scores

# %%
def make_hypothesis_tree_noscore(detections, faunastep):
    branches = []
#     scores = []

    times = detections.time.unique()
    times.sort()

    # todo:
    #     pre-generate probabilities between all the detections

    # go through each timestep
    for t in times:
        print("timestep: {}".format(t))

        # get all detections made at that timestep
        det_t = detections[detections["time"] == t]

        # make some lists to fill
        new_branches = []
#         new_scores = []

        # iterate over the detections
        for i, d in det_t.iterrows():
#             print(d["id"])
            if t == 0:
                new_br = np.array([d["id"]])
#                 new_score = 1

                new_branches.append(new_br)
#                 new_scores.append(new_score)

            else:
                # create new vector (case where this detection is a new individual)
                new_br = np.empty(t + 1)
                new_br[:] = np.NaN
                new_br[t] = d["id"]

                # add this to the new branches for this timestep
                new_branches.append(new_br)

                # add a score (of zero) for this case
#                 new_scores.append(1)

                # iterate over existing branches
                for i, br in enumerate(branches):
                    # get the id of the last detection in the current branch
                    last_detection = np.array(br)[np.logical_not(np.isnan(br))][-1]

                    # case where this is a repeat of the last observed
                    new_br_repeat = np.append(br, d["id"])
                    new_branches.append(new_br_repeat)

                    # calculate score
#                     scr = calc_score_row(detections[detections["id"] == last_detection], d, faunastep)
                    
#                     scr = probz[int(last_detection), int(d["id"])]

                    #                 print(len(scores), len(new_scores))
#                     new_scores.append(scores[i] + scr)

                    # case where it's not
                    new_br_no_repeat = np.append(br, np.NaN)
                    new_branches.append(new_br_no_repeat)

#                     new_scores.append(scores[i] + 1 - scr)

            branches = new_branches
#             scores = new_scores
    return branches

# %%
b, s= make_hypothesis_tree_noscore(detections, faunastep)
# Out:
# timestep: 0
# timestep: 1
# timestep: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-e44e0fe3a9e0> in <module>
# ----> 1 b, s= make_hypothesis_tree_noscore(detections, faunastep)
#
# <ipython-input-36-9dc24f83113c> in make_hypothesis_tree_noscore(detections, faunastep)
#      45                 for i, br in enumerate(branches):
#      46                     # get the id of the last detection in the current branch
# ---> 47                     last_detection = np.array(br)[np.logical_not(np.isnan(br))][-1]
#      48
#      49                     # case where this is a repeat of the last observed
#
# KeyboardInterrupt:
